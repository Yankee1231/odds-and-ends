# %% [markdown]
# <a href="https://colab.research.google.com/github/Yankee1231/odds-and-ends/blob/main/Control_Eng2_Week7_practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install control
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.9/513.9 kB 3.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import control as ctl
import matplotlib.pyplot as plt

# %%
J = 0.01
b = 0.1
K = 0.01
R = 1
L = 0.5
s = ctl.tf([1,0],[1])
G = K/((J*s+b)*(L*s+R)+K**2)

Kp = 500
Ki = 300
Kd = 30
C = Kp + Ki/s + Kd*s
sys_cl = ctl.feedback(C*G, 1)

t, y = ctl.step_response(sys_cl, np.arange(0, 0.5, 0.01))
plt.plot(t, y)
plt.xlabel('Time')
plt.title('Response of Motor PID System')
plt.axis([0, 0.5, 0, 1.1])

info = ctl.step_info(sys_cl)
for item in info:
  print(item, format(info[item],'.2f'))
# Out:
# Text(0.5, 1.0, 'Response of Motor PID System')
